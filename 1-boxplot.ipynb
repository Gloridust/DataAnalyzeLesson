# %%
import pandas as pd
import numpy as pd
arr = [900,32,23,43,34,2342,2333,12,14,15,24,29,-200]
arr
# Out:
# [900, 32, 23, 43, 34, 2342, 2333, 12, 14, 15, 24, 29, -200]

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']='Simhei'
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(8,8))
plt.ylim(-250,1000)
arr.boxplot(x=arr)
plt.rc('font',size=10)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 6
#       4 plt.figure(figsize=(8,8))
#       5 plt.ylim(-250,1000)
# ----> 6 arr.boxplot(x=arr)
#       7 plt.rc('font',size=10)
#       8 plot.show()
#
# AttributeError: 'list' object has no attribute 'boxplot'
